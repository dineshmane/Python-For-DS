# %% [markdown]
# ### Imports

# %%
import pandas as pd
from IPython.display import display, HTML
import numpy as np
#from TAS_Python_Utilities import data_viz
from sklearn import neural_network
from sklearn import metrics

# %%
import subprocess
from IPython.display import display, HTML, Image
import io as io
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz
from sklearn import preprocessing

# %% [markdown]
# ### Loading dataset

# %%
df = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df.head()
# Out:
#   class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002  \
# 0   neg   76698     na  2130706438    280      0      0      0      0      0
# 1   neg   33058     na           0     na      0      0      0      0      0
# 2   neg   41040     na         228    100      0      0      0      0      0
# 3   neg      12      0          70     66      0     10      0      0      0
# 4   neg   60874     na        1368    458      0      0      0      0      0
#
#    ...     ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009  \
# 0  ...    1240520  493384  721044  469792  339156  157956   73224      0
# 1  ...     421400  178064  293306  245416  133654   81140   97576   1500
# 2  ...     277378  159812  423992  409564  320746  158022   95128    514
# 3  ...        240      46      58      44      10       0       0      0
# 4  ...     622012  229790  405298  347188  286954  311560  433954   1218
#
#   ef_000 eg_000
# 0      0      0
# 1      0      0
# 2      0      0
# 3      4     32
# 4      0      0
#
# [5 rows x 171 columns]

# %% [markdown]
# <b>Null Value checks </b>
# <br> No NULL columns presents so targetting "na" string literal

# %%
display(df[df.isnull().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [class, aa_000, ab_000, ac_000, ad_000, ae_000, af_000, ag_000, ag_001, ag_002, ag_003, ag_004, ag_005, ag_006, ag_007, ag_008, ag_009, ah_000, ai_000, aj_000, ak_000, al_000, am_0, an_000, ao_000, ap_000, aq_000, ar_000, as_000, at_000, au_000, av_000, ax_000, ay_000, ay_001, ay_002, ay_003, ay_004, ay_005, ay_006, ay_007, ay_008, ay_009, az_000, az_001, az_002, az_003, az_004, az_005, az_006, az_007, az_008, az_009, ba_000, ba_001, ba_002, ba_003, ba_004, ba_005, ba_006, ba_007, ba_008, ba_009, bb_000, bc_000, bd_000, be_000, bf_000, bg_000, bh_000, bi_000, bj_000, bk_000, bl_000, bm_000, bn_000, bo_000, bp_000, bq_000, br_000, bs_000, bt_000, bu_000, bv_000, bx_000, by_000, bz_000, ca_000, cb_000, cc_000, cd_000, ce_000, cf_000, cg_000, ch_000, ci_000, cj_000, ck_000, cl_000, cm_000, ...]
# Index: []
#
# [0 rows x 171 columns]

# %%
a = df.select_dtypes(include=[np.object]).describe()
na_cols = a.columns[a.loc["top"][:] == "na"]
print("Number of columns having na values", len(na_cols))
# Out:
# Number of columns having na values 47

# %% [markdown]
# ### na_df which has only NA columns

# %%
na_df = df[na_cols]
na_df.head()
# Out:
#   ab_000 ad_000   ah_000   an_000   ao_000   ap_000   aq_000   bb_000  \
# 0     na    280  2551696  4933296  3655166  1766008  1132040  6700214
# 1     na     na  1393352  2560898  2127150  1084598   338544  3646660
# 2     na    100  1234132  2371990  2173634   300796   153698  2673338
# 3      0     66     2668    10184     7554    10764     1014    21614
# 4     na    458  1974038  3230626  2618878  1058136   551022  4289260
#
#     bg_000 bh_000  ...    cx_000  cz_000   dc_000 dd_000 de_000 dn_000  \
# 0  2551696  97518  ...     51288  532572  5330690   4732   1126  62282
# 1  1393352  49028  ...        na      na       na   3312    522  33736
# 2  1234132  28804  ...     29188   20346  2341048   1494    152  13876
# 3     2668    184  ...        72      12     2578     76     62    232
# 4  1974038  86454  ...    215826    4262  3590004   2026    444  44946
#
#    ds_000 dt_000    ec_00 ed_000
# 0  202710  37928   2445.8   2712
# 1  103330  16254  2211.76   2334
# 2   65772  10534  1018.64   1020
# 3      48     18     1.08     54
# 4  149474  35154  1116.06   1176
#
# [5 rows x 47 columns]

# %% [markdown]
# #### Vizulazing the data distribution in dataframe
# segregating the "na" and "non-na" values

# %%
# Function used to display the data distribution
def data_viz(df):
    # Plot histograms for numeric columns
    for idx, col in enumerate(df.select_dtypes(include=[np.number]).keys()):
        df[col].plot.hist(title = col)
        plt.show()

    # Plot bar plots  for categorical/boolean columns        
    for idx, col in enumerate(df.select_dtypes(include=[np.object, np.bool]).keys()):
        # Only draw bar plots for variables with less than 30 levels
        if len(df[col].unique()) < 30:
            df[col].value_counts().plot.bar(title = col)
            plt.show()

# %%
na_df = na_df[na_df.iloc[:][:] == "na"]
na_df1 = na_df
na_df1 = na_df1.fillna("non-na")
data_viz(na_df1)

# %%
threshold_list =[]
for col in na_cols:
    if na_df1[col].value_counts()[1] > 15000:
        threshold_list.append(col)
print("These are the column names which has more NA values than threshold :", threshold_list)
# Out:
# These are the column names which has more NA values than threshold : ['bk_000', 'bl_000', 'bm_000', 'bn_000']

# %% [markdown]
# Removing threshold columns from the dataset

# %%
df2 = df[df.columns.difference(threshold_list)]
df2.head()
# Out:
#    aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001 ag_002 ag_003  \
# 0   76698     na  2130706438    280      0      0      0      0      0      0
# 1   33058     na           0     na      0      0      0      0      0      0
# 2   41040     na         228    100      0      0      0      0      0      0
# 3      12      0          70     66      0     10      0      0      0    318
# 4   60874     na        1368    458      0      0      0      0      0      0
#
#    ...     ee_002  ee_003  ee_004  ee_005  ee_006  ee_007  ee_008 ee_009  \
# 0  ...    1240520  493384  721044  469792  339156  157956   73224      0
# 1  ...     421400  178064  293306  245416  133654   81140   97576   1500
# 2  ...     277378  159812  423992  409564  320746  158022   95128    514
# 3  ...        240      46      58      44      10       0       0      0
# 4  ...     622012  229790  405298  347188  286954  311560  433954   1218
#
#   ef_000 eg_000
# 0      0      0
# 1      0      0
# 2      0      0
# 3      4     32
# 4      0      0
#
# [5 rows x 167 columns]

# %%
X_train = df2[df2.columns.difference(["class"])]
Y_train = np.array(df2["class"])

# we have selected the columns which we have choosen for the train dataset
X_test = df_test[df2.columns.difference(["class"])]
Y_test = np.array(df_test["class"])

# %%
'''
X_train = X_train.replace("na",np.nan)
X_test = X_test.replace("na",np.nan)
X_train = X_train.astype('float64')
X_train = X_train.fillna(X_train.mean())
'''
# Out:
# '\nX_train = X_train.replace("na",np.nan)\nX_test = X_test.replace("na",np.nan)\nX_train = X_train.astype(\'float64\')\nX_train = X_train.fillna(X_train.mean())\n'

# %%
X_train = X_train.replace("na",np.nan)
X_test = X_test.replace("na",np.nan)

X_train = X_train.astype('float64')
X_train = X_train.fillna(X_train.mean())

X_test = X_test.astype('float64')
X_test = X_test.fillna(X_test.mean())

# %%
# not working
#X_train = X_train.replace("na",np.nan)
#X_test = X_test.replace("na",np.nan)

#X_train = X_train.apply(lambda x: x.fillna(x.mean()),axis=0)
#X_test = X_test.apply(lambda x: x.fillna(x.mean()),axis=0)

# %%
'''
from sklearn import preprocessing
X_train = X_train.astype('float64', raise_on_error = False).dtypes
X_test= X_test.astype('float64', raise_on_error = False).dtypes

X_train = X_train.replace("na", np.nan)
X_train = X_train.fillna(X_train.mean())
'''
# Out:
# '\nfrom sklearn import preprocessing\nX_train = X_train.astype(\'float64\', raise_on_error = False).dtypes\nX_test= X_test.astype(\'float64\', raise_on_error = False).dtypes\n\nX_train = X_train.replace("na", np.nan)\nX_train = X_train.fillna(X_train.mean())\n'

# %%
'''
X_test = X_test.replace("na",-8983035554)
X_test = X_test.replace(-8983035554, np.nan)
X_test = X_test.fillna(X_train.mean())
'''
# Out:
# '\nX_test = X_test.replace("na",-8983035554)\nX_test = X_test.replace(-8983035554, np.nan)\nX_test = X_test.fillna(X_train.mean())\n'

# %%
# Getting normalized data for train
x = X_train.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
X_train = pd.DataFrame(x_scaled)


x = X_test.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
X_test = pd.DataFrame(x_scaled)

# %%
'''
## Normalize train and test data


# Getting normalized data for train
x = X_train.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
X_train = pd.DataFrame(x_scaled)

# Getting normalized data for test
x = X_test.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
X_test = pd.DataFrame(x_scaled)

'''
# Out:
# '\n## Normalize train and test data\n\n\n# Getting normalized data for train\nx = X_train.values #returns a numpy array\nmin_max_scaler = preprocessing.MinMaxScaler()\nx_scaled = min_max_scaler.fit_transform(x)\nX_train = pd.DataFrame(x_scaled)\n\n# Getting normalized data for test\nx = X_test.values #returns a numpy array\nmin_max_scaler = preprocessing.MinMaxScaler()\nx_scaled = min_max_scaler.fit_transform(x)\nX_test = pd.DataFrame(x_scaled)\n\n'

# %% [markdown]
# ### Evaluating Model Performance

# %%
my_nn = neural_network.MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(50,100,50,), momentum=0.9,
       shuffle=True, solver='adam', validation_fraction=0.1, warm_start=False)
my_nn.fit(X_train,Y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(50, 100, 50), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
# Make a set of predictions for the test data
y_test = Y_test
y_pred = my_nn.predict(X_test)

# Print performance details
accuracy = metrics.accuracy_score(y_test, y_pred) # , normalize=True, sample_weight=None
print("Accuracy: " +  str(accuracy))
print(metrics.classification_report(y_test, y_pred))

# Print confusion matrix
print(metrics.confusion_matrix(y_test, y_pred))

# Print nicer confusion matrix
print("Confusion Matrix")
pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Accuracy: 0.9829375
#              precision    recall  f1-score   support
#
#         neg       0.98      1.00      0.99     15625
#         pos       0.96      0.29      0.44       375
#
# avg / total       0.98      0.98      0.98     16000
#
# [[15620     5]
#  [  268   107]]
# Confusion Matrix
# Predicted    neg  pos    All
# True
# neg        15620    5  15625
# pos          268  107    375
# All        15888  112  16000
